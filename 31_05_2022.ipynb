# %% [markdown]
# <a href="https://colab.research.google.com/github/sreekar-1726/python-practice/blob/main/31_05_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#pyplot
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([5, 9])
ypoints = np.array([10, 20])

plt.plot(xpoints, ypoints)
plt.show()

# %%
#plotting
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([4, 8])
ypoints = np.array([5, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
#plotting
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([4, 8])
ypoints = np.array([6, 10])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
#plotting
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([3, 6, 8, 10])
ypoints = np.array([5, 8, 3, 13])

plt.plot(xpoints, ypoints)
plt.show()

# %%
#plotting
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([4, 8, 11, 12, 15, 17])

plt.plot(ypoints)
plt.show()

# %%
#markers
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([13, 14, 11, 10])

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
#markers
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([14, 15, 18, 10])

plt.plot(xpoints, marker = 'o')
plt.show()

# %%
#markers
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([14, 15, 18, 10])

plt.plot(ypoints, marker = '*')
plt.show()

# %%
#markers
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([13, 15, 18, 20])

plt.plot(xpoints, marker = '*')
plt.show()

# %%
#markers
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([4, 6, 8, 10])

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
#markers
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([11, 13, 17, 20])

plt.plot(xpoints, marker = 'o')
plt.show()

# %%
#markers
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([5,7,9,12,15])

plt.plot(ypoints, marker = '*')
plt.show()

# %%
#markers
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([20, 25, 30, 35])

plt.plot(xpoints, marker = '*')
plt.show()

# %%
#markers
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([20,25,30,35])

plt.plot(xpoints, marker = '*')
plt.show()

# %%
#line
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([4, 8, 3, 11])

plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
#line
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([4, 8, 3, 11])

plt.plot(ypoints, linestyle = 'dashed')
plt.show()

# %%
#line
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([4, 8, 3, 11])

plt.plot(ypoints, ls = ':')
plt.show()

# %%
#line
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([4, 8, 11, 15])

plt.plot(ypoints, color = 'r')
plt.show()

# %%
#line
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([4, 8, 5, 15])

plt.plot(ypoints, color = 'g')
plt.show()

# %%
#line
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([5, 9, 14, 18])

plt.plot(ypoints, linewidth = '10.5')
plt.show()

# %%
#line
import matplotlib.pyplot as plt
import numpy as np

y1 = np.array([4, 8, 14, 18])
y2 = np.array([16, 12, 17, 15])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %%
#labels
import numpy as np
import matplotlib.pyplot as plt

x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

plt.plot(x, y)

plt.xlabel("subjects")
plt.ylabel("marks")

plt.show()

# %%
#lables
import numpy as np
import matplotlib.pyplot as plt

x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

plt.plot(x, y)

plt.title("Subjects")
plt.xlabel("marks")
plt.ylabel("marks of sem")

plt.show()

# %%
#lables
import numpy as np
import matplotlib.pyplot as plt

x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

font1 = {'family':'serif','color':'green','size':20}
font2 = {'family':'serif','color':'blue','size':15}

plt.title("semister graph", fontdict = font1)
plt.xlabel("subjects", fontdict = font2)
plt.ylabel("grades", fontdict = font2)

plt.plot(x, y)
plt.show()

# %%
#lables
import numpy as np
import matplotlib.pyplot as plt

x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])


plt.title("marks of sem", loc = 'left')
plt.xlabel("subjects")
plt.ylabel("marks")

plt.plot(x, y)
plt.show()

# %%
#lables
import numpy as np
import matplotlib.pyplot as plt

x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

font1 = {'family':'serif','color':'red','size':20}
font2 = {'family':'serif','color':'blue','size':15}

plt.title("semister graph", fontdict = font1)
plt.xlabel("subjects", fontdict = font2)
plt.ylabel("grades", fontdict = font2)

plt.plot(x, y)
plt.show()

# %%
#lables
import numpy as np
import matplotlib.pyplot as plt

x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])


plt.title("marks of sem", loc = 'right')
plt.xlabel("subjects")
plt.ylabel("marks")

plt.plot(x, y)
plt.show()

# %%
#grid
import numpy as np
import matplotlib.pyplot as plt

x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])


plt.title("marks of sem")
plt.xlabel("subjects")
plt.ylabel("marks")

plt.plot(x, y)

plt.grid()

plt.show()

# %%
#grid
import numpy as np
import matplotlib.pyplot as plt

x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])


plt.title("marks of sem")
plt.xlabel("subjects")
plt.ylabel("marks")

plt.plot(x, y)

plt.grid(axis = 'x')

plt.show()

# %%
#grid
import numpy as np
import matplotlib.pyplot as plt

x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])


plt.title("marks of sem")
plt.xlabel("subjects")
plt.ylabel("marks")

plt.plot(x, y)

plt.grid(axis = 'y')

plt.show()

# %%
#grid
import numpy as np
import matplotlib.pyplot as plt

x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])


plt.title("marks of sem")
plt.xlabel("subjects")
plt.ylabel("marks")


plt.plot(x, y)

plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)

plt.show()

# %%
#subplot
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y = np.array([9,8.5,7,7.5,7.8,8,9,9.4,7,])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
#subplot
#plot 1:
x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y = np.array([9,8.5,7,7.5,7.8,8,9,9.4,7,])


plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
#subplot
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("sem-1")

#plot 2:
x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y = np.array([9,8.5,7,7.5,7.8,8,9,9.4,7,])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("sem-2")

plt.show()

# %%
#subplot
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("sem-1")

#plot 2:
x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y = np.array([9,8.5,7,7.5,7.8,8,9,9.4,7,])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("sem-2")

plt.suptitle("semister marks")
plt.show()

# %%
#subplot
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %%
#scatter
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])

plt.scatter(x, y)
plt.show()

# %%
#scatter
import matplotlib.pyplot as plt
import numpy as np

#plot1
x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])
plt.scatter(x, y)

#plot2
x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y = np.array([9,8.5,7,7.5,7.8,8,9,9.4,7,])
plt.scatter(x, y)

plt.show()

# %%
#scatter
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])
plt.scatter(x, y, color = 'green')

x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y = np.array([9,8.5,7,7.5,7.8,8,9,9.4,7,])
plt.scatter(x, y, color = 'blue')

plt.show()

# %%
#scatter
#scatter
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])
plt.scatter(x, y, color = 'hotpink')

x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y = np.array([9,8.5,7,7.5,7.8,8,9,9.4,7,])
plt.scatter(x, y, color = 'blue')

plt.show()

# %%
#scatter
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige"])

plt.scatter(x, y, c=colors)

plt.show()

# %%
#scatter
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])
plt.scatter(x, y, color = 'hotpink')

x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y = np.array([9,8.5,7,7.5,7.8,8,9,9.4,7,])
plt.scatter(x, y, color = 'green')

plt.show()

# %%
#scatter
import matplotlib.pyplot as plt
import numpy as np

x = np.array(['clad','it','comp','math-1','math-2','phy','mec','vdc','eng'])
y= np.array(['8','8','9','9.2','9.3','8','9.4','7.8','8.1'])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige"])

plt.scatter(x, y, c=colors)

plt.show()

# %%
#scatter
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.colorbar()

plt.show()

# %%
#scatter
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.show()

# %%
#bars
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([4, 8, 12, 16])

plt.bar(x,y)
plt.show()

# %%
#bars
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([4, 8, 12, 16])

plt.barh(x, y)
plt.show()

# %%
#bars
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([4, 8, 12, 16])

plt.bar(x, y, color = "red")
plt.show()

# %%
#bars
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([4, 8, 12, 16])

plt.bar(x, y, color = "green")
plt.show()

# %%
#bars
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([4, 8, 12, 16])

plt.bar(x, y, color = "hotpink")
plt.show()

# %%
#bars
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([4, 9, 5, 17])

plt.bar(x, y, width = 0.1)
plt.show()

# %%
#bars
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([4, 8, 6, 15])

plt.barh(x, y, height = 0.1)
plt.show()

# %%
#histogram
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 100, 250)

plt.hist(x)
plt.show()

# %%
#histogram
import numpy as np

x = np.random.normal(160, 100, 200)

print(x)
# Out:
# [280.40460549 137.79520049 151.47584047 118.55714583 114.43581686
#  110.54563646 184.89271554  98.70254311 165.63125087 154.70866718
#  190.99567846  28.94810825 292.04196531 136.39380285 -23.62697799
#  173.77527951  93.94119372  88.31856226 251.16394442 149.27020295
#  297.276055    60.95302111 229.27257825  99.41222468 203.53821609
#  331.46290193 118.86765654 297.62692736  37.82987766 108.232777
#  129.49015354 225.96604936 257.64907724  98.64033942  79.79443548
#  183.88479982 288.00346719 325.58847236  49.9555513  111.99316129
#  257.51430122 -43.07647716  91.42781648 128.83662084 124.15340854
#   48.97921555 265.58375051 383.75026096  72.15427739 236.96563363
#   44.31087262 327.57443283 140.42574858 169.55950271  61.93510702
#  251.62887779 119.89482248 212.02764358 -39.17942791  73.90752781
#   73.11151812 137.04258637 151.34566181 192.50498474 264.19942193
#   92.08963781  71.65653909 399.76738805  88.32203213 226.18735858
#  234.24642844  18.5737728  290.75878783 145.99827263 176.77829157
#   34.96211842 122.57018253 205.69899078 109.41565639 282.95680461
#  183.32092712 316.64029663 101.29046368 296.13838958 -49.17827824
#  479.35100361 181.41333381 -65.36701486 204.36569433 121.13878422
#  327.69666439 156.8980801  232.74064307 190.96893731 287.48113234
#  149.8249702  193.93218502 210.7054878  311.04618565 170.19724945
#  154.49726178 239.31770778  85.53905767 263.57651948 200.0294934
#  -21.02337515 240.64434413  39.7498541  140.86064196  66.36608862
#  101.17244221 -53.48599364 368.20048339 229.51825507 176.97313255
#  183.25710438 185.79489445  93.71496303 241.47051576 254.5245666
#   28.79744911 128.22524578 177.14872645 105.94362282 197.17836071
#  193.26997061 167.59834951 298.80252999 175.72468649 150.89688066
#  333.98512089 237.48069665 123.20307098  84.72398914 265.91764869
#  158.75961878 214.44735149 287.7837006  256.62270785 127.39658162
#  125.22374822 130.03633645 187.03284092  98.40035384 301.39492157
#  363.5165549  -35.74417189 210.78186539 352.48779604 174.92975823
#  135.056647   121.83857715 307.9639936  131.04746558  27.05317111
#  153.69427558 193.84446948  93.04320938 220.33243917 257.20119827
#  317.7594949  201.52394587 145.10579887  75.54242679 294.59148472
#  192.59355651  35.68209035 203.40800007 191.64090475 159.5297516
#   90.87343158 -55.21716843 281.12159851 307.2598612   -1.07040956
#  237.90672492  83.80829046 193.4338469   80.64284965 230.82042704
#  289.39701329 266.2424776  201.10221722  40.07492139 126.77161105
#   99.13287934 134.46754441 161.99165089 122.41790332 272.04303277
#  192.02228883  -1.28286354 -37.77101466  27.03200276 -19.93379768
#  326.35165915 173.38647696 168.43335157 195.22854961  55.65763112]

# %%
#histogram
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(160, 100, 250)

plt.hist(x)
plt.show()

# %%
#pie chart
import matplotlib.pyplot as plt
import numpy as np

y = np.array([20, 25, 30, 35])

plt.pie(y)
plt.show()

# %%
#pie chart
import matplotlib.pyplot as plt
import numpy as np

y = np.array([20, 25, 30, 35])
mylabels = ["Apples", "Bananas", "Cherries", "mangos"]

plt.pie(y, labels = mylabels)
plt.show()

# %%
#pie chart
import matplotlib.pyplot as plt
import numpy as np

y = np.array([20, 25, 30, 35])
mylabels = ["Apples", "Bananas", "Cherries", "mangos"]

plt.pie(y, labels = mylabels, startangle = 90)
plt.show()

# %%
#pie chart
import matplotlib.pyplot as plt
import numpy as np

y = np.array([20, 25, 30, 35])
mylabels = ["Apples", "Bananas", "Cherries", "mangos"]
myexplode = [0.2, 0.3, 0.4, 0.5]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %%
#pie chart
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "mangos"]
myexplode = [0.2, 0.1, 0.3, 0.1]

plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()

# %%
#pie chart
import matplotlib.pyplot as plt
import numpy as np

y = np.array([20, 25, 30, 35])
mylabels = ["Apples", "Bananas", "Cherries", "mangos"]

plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %%
#pie chart
import matplotlib.pyplot as plt
import numpy as np

y = np.array([20,25,30,35])
mylabels = ["Apples", "Bananas", "Cherries", "mangos"]

plt.pie(y, labels = mylabels)
plt.legend(title = " Fruits:")
plt.show()

# %%
#pie chart
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "mangos"]
mycolors = ["black", "hotpink", "blue", "green"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %%
#pie chart
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "mangos"]
mycolors = ["black", "yellow", "orange", "green"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %%
#pie chart
import matplotlib.pyplot as plt
import numpy as np

x = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0.4, 0.3, 0]

plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()
